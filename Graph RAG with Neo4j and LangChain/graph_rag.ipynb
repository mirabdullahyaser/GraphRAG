# %%
import getpass
import os
from dotenv import load_dotenv
from langchain_community.graphs import Neo4jGraph
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 6
#       4 from langchain_community.graphs import Neo4jGraph
#       5 from langchain_experimental.graph_transformers import LLMGraphTransformer
# ----> 6 from langchain_openai import ChatOpenAI
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\langchain_openai\__init__.py:1
# ----> 1 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       2 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       3 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\langchain_openai\chat_models\__init__.py:1
# ----> 1 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       2 from langchain_openai.chat_models.base import ChatOpenAI
#       4 __all__ = ["ChatOpenAI", "AzureChatOpenAI"]
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\langchain_openai\chat_models\azure.py:23
#       7 from operator import itemgetter
#       8 from typing import (
#       9     Any,
#      10     Callable,
#    (...)
#      20     overload,
#      21 )
# ---> 23 import openai
#      24 from langchain_core.language_models import LanguageModelInput
#      25 from langchain_core.language_models.chat_models import LangSmithParams
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\openai\__init__.py:8
#       5 import os as _os
#       6 from typing_extensions import override
# ----> 8 from . import types
#       9 from ._types import NOT_GIVEN, NoneType, NotGiven, Transport, ProxiesTypes
#      10 from ._utils import file_from_path
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\openai\types\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from __future__ import annotations
# ----> 5 from .batch import Batch as Batch
#       6 from .image import Image as Image
#       7 from .model import Model as Model
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\openai\types\batch.py:7
#       4 from typing import List, Optional
#       5 from typing_extensions import Literal
# ----> 7 from .._models import BaseModel
#       8 from .batch_error import BatchError
#       9 from .batch_request_counts import BatchRequestCounts
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\openai\_models.py:25
#      22 import pydantic.generics
#      23 from pydantic.fields import FieldInfo
# ---> 25 from ._types import (
#      26     Body,
#      27     IncEx,
#      28     Query,
#      29     ModelT,
#      30     Headers,
#      31     Timeout,
#      32     NotGiven,
#      33     AnyMapping,
#      34     HttpxRequestFiles,
#      35 )
#      36 from ._utils import (
#      37     PropertyInfo,
#      38     is_list,
#    (...)
#      48     strip_annotated_type,
#      49 )
#      50 from ._compat import (
#      51     PYDANTIC_V2,
#      52     ConfigDict,
#    (...)
#      61     field_get_default,
#      62 )
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\openai\_types.py:21
#       4 from typing import (
#       5     IO,
#       6     TYPE_CHECKING,
#    (...)
#      17     Sequence,
#      18 )
#      19 from typing_extensions import Literal, Protocol, TypeAlias, TypedDict, override, runtime_checkable
# ---> 21 import httpx
#      22 import pydantic
#      23 from httpx import URL, Proxy, Timeout, Response, BaseTransport, AsyncBaseTransport
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\httpx\__init__.py:2
#       1 from .__version__ import __description__, __title__, __version__
# ----> 2 from ._api import delete, get, head, options, patch, post, put, request, stream
#       3 from ._auth import Auth, BasicAuth, DigestAuth, NetRCAuth
#       4 from ._client import USE_CLIENT_DEFAULT, AsyncClient, Client
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\httpx\_api.py:6
#       3 import typing
#       4 from contextlib import contextmanager
# ----> 6 from ._client import Client
#       7 from ._config import DEFAULT_TIMEOUT_CONFIG
#       8 from ._models import Response
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\httpx\_client.py:12
#       9 from types import TracebackType
#      11 from .__version__ import __version__
# ---> 12 from ._auth import Auth, BasicAuth, FunctionAuth
#      13 from ._config import (
#      14     DEFAULT_LIMITS,
#      15     DEFAULT_MAX_REDIRECTS,
#    (...)
#      19     Timeout,
#      20 )
#      21 from ._decoders import SUPPORTED_DECODERS
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\httpx\_auth.py:12
#       9 from urllib.request import parse_http_list
#      11 from ._exceptions import ProtocolError
# ---> 12 from ._models import Cookies, Request, Response
#      13 from ._utils import to_bytes, to_str, unquote
#      15 if typing.TYPE_CHECKING:  # pragma: no cover
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\httpx\_models.py:11
#       8 from collections.abc import Mapping
#       9 from http.cookiejar import Cookie, CookieJar
# ---> 11 from ._content import ByteStream, UnattachedStream, encode_request, encode_response
#      12 from ._decoders import (
#      13     SUPPORTED_DECODERS,
#      14     ByteChunker,
#    (...)
#      20     TextDecoder,
#      21 )
#      22 from ._exceptions import (
#      23     CookieConflict,
#      24     HTTPStatusError,
#    (...)
#      29     request_context,
#      30 )
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\httpx\_content.py:17
#      14 from urllib.parse import urlencode
#      16 from ._exceptions import StreamClosed, StreamConsumed
# ---> 17 from ._multipart import MultipartStream
#      18 from ._types import (
#      19     AsyncByteStream,
#      20     RequestContent,
#    (...)
#      24     SyncByteStream,
#      25 )
#      26 from ._utils import peek_filelike_length, primitive_value_to_str
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\httpx\_multipart.py:8
#       5 import typing
#       6 from pathlib import Path
# ----> 8 from ._types import (
#       9     AsyncByteStream,
#      10     FileContent,
#      11     FileTypes,
#      12     RequestData,
#      13     RequestFiles,
#      14     SyncByteStream,
#      15 )
#      16 from ._utils import (
#      17     format_form_param,
#      18     guess_content_type,
#    (...)
#      21     to_bytes,
#      22 )
#      25 def get_multipart_boundary_from_content_type(
#      26     content_type: bytes | None,
#      27 ) -> bytes | None:
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\httpx\_types.py:5
#       1 """
#       2 Type definitions for type checking purposes.
#       3 """
# ----> 5 import ssl
#       6 from http.cookiejar import CookieJar
#       7 from typing import (
#       8     IO,
#       9     TYPE_CHECKING,
#    (...)
#      24     Union,
#      25 )
#
# File ~\anaconda3\lib\ssl.py:98
#      95 from collections import namedtuple
#      96 from enum import Enum as _Enum, IntEnum as _IntEnum, IntFlag as _IntFlag
# ---> 98 import _ssl             # if we can't import it, let the error propagate
#     100 from _ssl import OPENSSL_VERSION_NUMBER, OPENSSL_VERSION_INFO, OPENSSL_VERSION
#     101 from _ssl import _SSLContext, MemoryBIO, SSLSession
#
# ImportError: DLL load failed while importing _ssl: The specified module could not be found.

# %% [markdown]
# Load All Environment Variables for OPENAI API and Neo4jGraph APIs

# %%
load_dotenv()
# Out:
# True

# %%
graph = Neo4jGraph(refresh_schema=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\langchain_community\graphs\neo4j_graph.py:341, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     340 try:
# --> 341     import neo4j
#     342 except ImportError:
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\neo4j\__init__.py:28
#      20 from ._api import (
#      21     NotificationCategory,
#      22     NotificationDisabledCategory,
#    (...)
#      26     RoutingControl,
#      27 )
# ---> 28 from ._async.driver import (
#      29     AsyncBoltDriver,
#      30     AsyncDriver,
#      31     AsyncGraphDatabase,
#      32     AsyncNeo4jDriver,
#      33 )
#      34 from ._async.work import (
#      35     AsyncManagedTransaction,
#      36     AsyncResult,
#      37     AsyncSession,
#      38     AsyncTransaction,
#      39 )
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\neo4j\_async\driver.py:96
#      95 from .config import AsyncPoolConfig
# ---> 96 from .work import (
#      97     AsyncManagedTransaction,
#      98     AsyncResult,
#      99     AsyncSession,
#     100 )
#     103 if t.TYPE_CHECKING:
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\neo4j\_async\work\__init__.py:16
#       1 # Copyright (c) "Neo4j"
#       2 # Neo4j Sweden AB [https://neo4j.com]
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
# ---> 16 from .result import (
#      17     AsyncResult,
#      18     EagerResult,
#      19 )
#      20 from .session import (
#      21     AsyncSession,
#      22     AsyncWorkspace,
#      23 )
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\neo4j\_async\work\result.py:64
#      63 from .._debug import AsyncNonConcurrentMethodChecker
# ---> 64 from ..io import ConnectionErrorHandler
#      67 if t.TYPE_CHECKING:
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\neo4j\_async\io\__init__.py:34
#      24 __all__ = [
#      25     "AcquireAuth",
#      26     "AsyncBolt",
#    (...)
#      30     "ConnectionErrorHandler",
#      31 ]
# ---> 34 from ._bolt import AsyncBolt
#      35 from ._common import (
#      36     check_supported_server_product,
#      37     ConnectionErrorHandler,
#      38 )
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\neo4j\_async\io\_bolt.py:27
#      26 from ..._api import TelemetryAPI
# ---> 27 from ..._async_compat.network import AsyncBoltSocket
#      28 from ..._async_compat.util import AsyncUtil
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\neo4j\_async_compat\network\__init__.py:17
#       1 # Copyright (c) "Neo4j"
#       2 # Neo4j Sweden AB [https://neo4j.com]
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
# ---> 17 from ._bolt_socket import (
#      18     AsyncBoltSocket,
#      19     BoltSocket,
#      20 )
#      21 from ._util import (
#      22     AsyncNetworkUtil,
#      23     NetworkUtil,
#      24 )
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:32
#      23 from socket import (
#      24     AF_INET,
#      25     AF_INET6,
#    (...)
#      30     timeout as SocketTimeout,
#      31 )
# ---> 32 from ssl import (
#      33     CertificateError,
#      34     HAS_SNI,
#      35     SSLError,
#      36     SSLSocket,
#      37 )
#      39 from ... import addressing
#
# File ~\anaconda3\lib\ssl.py:98
#      96 from enum import Enum as _Enum, IntEnum as _IntEnum, IntFlag as _IntFlag
# ---> 98 import _ssl             # if we can't import it, let the error propagate
#     100 from _ssl import OPENSSL_VERSION_NUMBER, OPENSSL_VERSION_INFO, OPENSSL_VERSION
#
# ImportError: DLL load failed while importing _ssl: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 graph = Neo4jGraph(refresh_schema=False)
#
# File x:\Github\GraphRAG\graph-rag-venv\lib\site-packages\langchain_community\graphs\neo4j_graph.py:343, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     341     import neo4j
#     342 except ImportError:
# --> 343     raise ImportError(
#     344         "Could not import neo4j python package. "
#     345         "Please install it with `pip install neo4j`."
#     346     )
#     348 url = get_from_dict_or_env({"url": url}, "url", "NEO4J_URI")
#     349 username = get_from_dict_or_env(
#     350     {"username": username}, "username", "NEO4J_USERNAME"
#     351 )
#
# ImportError: Could not import neo4j python package. Please install it with `pip install neo4j`.

# %%
import ssl
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import ssl
#
# File ~\anaconda3\lib\ssl.py:98
#      95 from collections import namedtuple
#      96 from enum import Enum as _Enum, IntEnum as _IntEnum, IntFlag as _IntFlag
# ---> 98 import _ssl             # if we can't import it, let the error propagate
#     100 from _ssl import OPENSSL_VERSION_NUMBER, OPENSSL_VERSION_INFO, OPENSSL_VERSION
#     101 from _ssl import _SSLContext, MemoryBIO, SSLSession
#
# ImportError: DLL load failed while importing _ssl: The specified module could not be found.
